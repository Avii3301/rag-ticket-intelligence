# %% [markdown]
# # Week 3 — RAG Pipeline
#
# This notebook demonstrates the full end-to-end RAG pipeline built this week.
#
# **Pipeline:**
# ```
# New ticket description
#     → ChromaDB vector search (top 20)
#     → Cross-encoder reranker (top 5)
#     → Mistral via Ollama
#     → Root cause + suggested resolution + confidence
# ```
#
# **Source files built this week:**
# - `src/retriever.py` — loads ChromaDB and runs similarity search
# - `src/reranker.py` — cross-encoder reranking with `ms-marco-MiniLM-L-6-v2`
# - `src/rag_chain.py` — LangChain chain wiring retriever → reranker → LLM
#
# > ChromaDB was populated in Week 2 (`src/embeddings.py`). We don't re-embed here.

# %% [markdown]
# ## 1. Setup

# %%
import sys
import os

# Add the project root to sys.path so `src.*` imports resolve correctly
# when running from the notebooks/ directory.
sys.path.insert(0, os.path.abspath(".."))
os.chdir("..")  # set working directory to project root so data/ paths resolve

from src.retriever import retrieve
from src.reranker import rerank
from src.rag_chain import run

print("Imports OK")
# Out:
# Imports OK

# %% [markdown]
# ## 2. Retriever
#
# `retrieve()` embeds the query with BGE and searches ChromaDB.
# We fetch `top_k=20` here — more than we need — because the reranker will trim this down.
# The `distance` field is the L2 distance between vectors: lower = more similar.

# %%
query = "My laptop won't connect to the VPN and I keep getting an authentication error"

candidates = retrieve(query, top_k=20)

print(f"Retrieved {len(candidates)} candidates\n")
for i, t in enumerate(candidates[:5], 1):  # print top 5 for inspection
    print(f"{i}. [{t['category']}] {t['subject']}")
    print(f"   Distance: {t['distance']:.4f}")
    print(f"   Resolution: {t['resolution'][:120]}...\n")
# Out:
# Retrieved 4 candidates
#
# 1. [Network] VPN certificate expired
#    Distance: 0.3822
#    Resolution: Renewed the client VPN certificate and pushed updated certificate bundle to user's machine via MDM. VPN connection resto...
#
# 2. [Network] VPN connection dropping repeatedly
#    Distance: 0.4617
#    Resolution: Identified split-tunnel misconfiguration causing keepalive timeouts. Updated VPN profile settings and pushed new configu...
#
# 3. [Network] Cannot connect to VPN from home
#    Distance: 0.4677
#    Resolution: User's ISP was blocking UDP port 4500 needed for VPN. Switched VPN profile to TCP/443 fallback mode. Connection establis...
#
# 4. [Network] VPN two-factor authentication not working
#    Distance: 0.4957
#    Resolution: Re-synced user's TOTP seed in the authentication server. Old seed had drifted. Generated new QR code for user to re-enro...

# %% [markdown]
# ## 3. Reranker
#
# `rerank()` scores every `(query, resolution)` pair using the cross-encoder.
# Unlike vector distance, the cross-encoder reads both texts together —
# it can catch relevance that pure embedding similarity misses.
#
# Notice the order may change from the retriever results above:
# a ticket ranked 8th by vector search might jump to 1st after reranking.

# %%
top_tickets = rerank(query, candidates, top_k=5)

print(f"Top {len(top_tickets)} after reranking:\n")
for i, t in enumerate(top_tickets, 1):
    print(f"{i}. [{t['category']}] {t['subject']}")
    print(f"   Rerank score: {t['rerank_score']:.4f}  |  Original distance: {t['distance']:.4f}")
    print(f"   Resolution: {t['resolution'][:120]}...\n")
# Out:
# Top 4 after reranking:
#
# 1. [Network] Cannot connect to VPN from home
#    Rerank score: -3.5008  |  Original distance: 0.4677
#    Resolution: User's ISP was blocking UDP port 4500 needed for VPN. Switched VPN profile to TCP/443 fallback mode. Connection establis...
#
# 2. [Network] VPN connection dropping repeatedly
#    Rerank score: -4.7057  |  Original distance: 0.4617
#    Resolution: Identified split-tunnel misconfiguration causing keepalive timeouts. Updated VPN profile settings and pushed new configu...
#
# 3. [Network] VPN certificate expired
#    Rerank score: -5.5010  |  Original distance: 0.3822
#    Resolution: Renewed the client VPN certificate and pushed updated certificate bundle to user's machine via MDM. VPN connection resto...
#
# 4. [Network] VPN two-factor authentication not working
#    Rerank score: -9.1111  |  Original distance: 0.4957
#    Resolution: Re-synced user's TOTP seed in the authentication server. Old seed had drifted. Generated new QR code for user to re-enro...

# %% [markdown]
# ## 4. Full RAG chain — single query
#
# `run()` executes all steps in sequence and returns:
# - `response` — the LLM's generated resolution suggestion
# - `sources` — the 5 tickets that were passed as context (for transparency)
#
# Model: **Mistral 7B via Ollama** (running locally on MPS).
# First call will be slower as the model loads into memory.

# %%
result = run(query, provider="ollama", model_name="mistral")

print("=" * 60)
print("QUERY")
print("=" * 60)
print(result["query"])

print("\n" + "=" * 60)
print("RESPONSE")
print("=" * 60)
print(result["response"])

print("\n" + "=" * 60)
print("SOURCES USED AS CONTEXT")
print("=" * 60)
for i, src in enumerate(result["sources"], 1):
    print(f"{i}. {src['subject']} (score: {src['rerank_score']:.3f})")
# Out:
# ============================================================
# QUERY
# ============================================================
# My laptop won't connect to the VPN and I keep getting an authentication error
#
# ============================================================
# RESPONSE
# ============================================================
#  Root cause: The issue might be related to an expired or incorrect VPN certificate, or a problem with two-factor authentication (2FA).
#
# Suggested resolution:
# 1. Check if the VPN certificate on your laptop is up-to-date. If it's expired, renew the certificate and push the updated bundle to your machine via MDM.
# 2. If the issue persists, verify that your 2FA settings are correct. If necessary, re-sync your TOTP seed in the authentication server and generate a new QR code for you to re-enroll in the authenticator app.
#
# Confidence: Medium - The symptoms of the new ticket align with both certificate expiration and 2FA issues from the resolved tickets. However, further investigation may be required to pinpoint the exact cause.
#
# ============================================================
# SOURCES USED AS CONTEXT
# ============================================================
# 1. Cannot connect to VPN from home (score: -3.501)
# 2. VPN connection dropping repeatedly (score: -4.706)
# 3. VPN certificate expired (score: -5.501)
# 4. VPN two-factor authentication not working (score: -9.111)

# %% [markdown]
# ## 5. Multiple examples
#
# Running 4 queries across different ticket categories to verify the pipeline
# generalises — not just good at one type of ticket.

# %%
example_queries = [
    "Outlook keeps crashing when I try to open attachments larger than 5MB",
    "New employee needs laptop provisioned and access to the HR system",
    "The shared printer on floor 3 is offline and nobody can print",
    "I accidentally deleted a folder from the shared drive, can it be recovered?",
]

for query in example_queries:
    result = run(query, provider="ollama", model_name="mistral")
    print("\n" + "=" * 60)
    print(f"QUERY: {result['query']}")
    print("=" * 60)
    print(result["response"])
    print(f"\nSources: {', '.join(s['subject'][:40] for s in result['sources'])}")
# Out:
# ============================================================
# QUERY: Outlook keeps crashing when I try to open attachments larger than 5MB
# ============================================================
#  Root cause: The issue might be related to insufficient system resources or an add-on conflict causing Outlook to crash when opening large attachments.
#
# Suggested resolution:
# 1. Check and close any unnecessary applications running in the background that may be consuming system resources.
# 2. Disable all third-party Outlook add-ons temporarily to determine if one of them is causing the issue. If disabling add-ons resolves the problem, re-enable them one by one until you find the culprit.
# 3. Increase the memory allocated to Outlook by modifying the Outlook registry settings or using a third-party utility like Outlook TuneUp.
# 4. Scan your system for viruses and malware using reliable security software, as infected files could cause unexpected crashes.
#
# Confidence: Medium - The resolved tickets suggest that issues with Outlook can be caused by corrupted profiles, indexing problems, oversized mailboxes, stale credentials, or add-on conflicts. In this case, the symptoms match an add-on conflict or insufficient system resources, as the crashes occur only when opening large attachments. However, it's also possible that a different issue is causing the problem, such as a specific attachment type being incompatible with Outlook or a hardware failure affecting memory management.
#
# Sources: Outlook won't open — stuck on loading pr, Outlook search not finding emails, Outlook not syncing — emails are hours b, Outlook keeps asking for password
#
# ============================================================
# QUERY: New employee needs laptop provisioned and access to the HR system
# ============================================================
#  Root cause: The issue is related to providing access and setting up equipment for a new employee.
#
# Suggested resolution: Provision a laptop for the new employee, install necessary software, set up VPN access if required, and grant access to the HR system. Send a welcome email with laptop details and credentials to the manager for distribution on the start date.
#
# Confidence: High - The pattern from the resolved tickets indicates that setting up equipment and providing access to systems is a common process for new employees in our organization.
#
# Sources: New employee needs account setup, New employee needs account setup, New employee needs account setup, New employee needs account setup, New employee needs account setup
#
# ============================================================
# QUERY: The shared printer on floor 3 is offline and nobody can print
# ============================================================
#  Root cause: The shared printer on floor 3 might be experiencing an issue with its service or network connectivity.
#
# Suggested resolution:
# 1. Check the status of the printer's service (print spooler) on the print server. If it's not running, restart the service.
# 2. Verify that the printer is connected to the network and powered on.
# 3. Clear any stuck print jobs from the print queue on the print server.
# 4. Test printing from a workstation on floor 3 to ensure the issue has been resolved.
#
# Confidence: High - The new ticket shares similarities with Ticket 1 (can't find network printer) and Ticket 2 (printer not printing), suggesting that the problem may be related to the print server service or network connectivity of the shared printer on floor 3.
#
# Sources: Can't find network printer, Printer not printing — jobs stuck in que
#
# ============================================================
# QUERY: I accidentally deleted a folder from the shared drive, can it be recovered?
# ============================================================
#  Root cause: The folder was deleted from the shared drive and needs recovery due to accidental deletion.
#
# Suggested resolution: Contact the user who deleted the folder and verify if they have a backup or any recent version of the folder. If not, escalate the issue to the system administrator for recovery from the backup server. In case of a successful recovery, restore the folder to its original location on the shared drive.
#
# Confidence: High - The resolution is based on the pattern observed in the resolved tickets, which all involve access-related issues related to shared drives. This new ticket involves data recovery from a shared drive, which is similar in nature and can be handled using similar steps.
#
# Sources: Need access to shared drive, Need access to shared drive, Need access to shared drive, Need access to shared drive, Need access to shared drive

# %% [markdown]
# ## Summary
#
# | Stage | Tool | Purpose |
# |---|---|---|
# | Embedding | `BAAI/bge-small-en` | Encode tickets + queries into vectors |
# | Vector search | ChromaDB | Fast approximate nearest-neighbour retrieval |
# | Reranking | `ms-marco-MiniLM-L-6-v2` | Precise relevance scoring on top-20 candidates |
# | Generation | Mistral 7B (Ollama) | Synthesise a resolution from retrieved context |
#
# **Week 4:** Fine-tune a classifier for ticket category + severity using scikit-learn → DistilBERT, tracked with MLflow.
